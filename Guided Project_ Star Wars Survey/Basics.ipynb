# %% [markdown]
# # Does the rest of America realize that “The Empire Strikes Back” is clearly the best of the bunch?

# %% [markdown]
# The team needed to collect data addressing this question. To do this, they surveyed Star Wars fans using the online tool SurveyMonkey.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
star_wars = pd.read_csv("star_wars.csv", encoding="ISO-8859-1")

# %%
star_wars.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                                Yes
# 1    3292879538                                                 No
# 2    3292765271                                                Yes
# 3    3292763116                                                Yes
# 4    3292731220                                                Yes
# 5    3292719380                                                Yes
# 6    3292684787                                                Yes
# 7    3292663732                                                Yes
# 8    3292654043                                                Yes
# 9    3292640424                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                                Yes
# 1                                                NaN
# ...

# %%
star_wars.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %%
yes_no = {
    "Yes": True,
    "No": False
}

star_wars['Have you seen any of the 6 films in the Star Wars franchise?']\
=star_wars['Have you seen any of the 6 films in the Star Wars franchise?'].map(yes_no)

star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?']\
=star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?'].map(yes_no)

# %%
star_map={star_wars.iloc[0,i]: True for i in range(3,9)}
star_map[np.NaN]=False

for i in range(3,9):
    star_wars[star_wars.columns[i]]=star_wars[star_wars.columns[i]].map(star_map)

print(star_wars[star_wars.columns[3:9]])
# Out:
#       Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0                                                  True
# 1                                                 False
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 1181                                               True
# 1182                                               True
# 1183                                              False
# 1184                                               True
# 1185                                               True
#
#       Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0           True        True        True        True        True
# 1          False       False       False       False       False
# ...

# %%
#rename columns 
star_wars = star_wars.rename(columns={star_wars.columns[i]: f'seen_{i-2}' for i in range(3,9)})

star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                               True
# 1    3292879538                                              False
# 2    3292765271                                               True
# 3    3292763116                                               True
# 4    3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  \
# 0    True    True    True    True    True    True
# 1   False   False   False   False   False   False
# 2    True    True    True   False   False   False
# ...

# %%
#convert columns to numeric types

star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)

# %%
#rename columns 
star_wars = star_wars.rename(columns={star_wars.columns[i]: f'ranking_{i-8}' for i in range(9,15)})

star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                               True
# 1    3292879538                                              False
# 2    3292765271                                               True
# 3    3292763116                                               True
# 4    3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  ranking_1  ...  \
# 0    True    True    True    True    True    True        3.0  ...
# 1   False   False   False   False   False   False        NaN  ...
# ...

# %% [markdown]
# # Find the highest ranked movie

# %%
ranking_mean=star_wars[star_wars.columns[9:15]].mean()
ranking_mean.plot(kind='bar')
plt.show()

# %% [markdown]
# We can clearly see that the 3rd movie is considered the worst (highest rating), while the 5th was considered the best.

# %% [markdown]
# ### How many people have seen each of the movies ?

# %%
seen_mean=star_wars[star_wars.columns[3:9]].sum()
seen_mean.plot(kind='bar')
plt.show()

# %% [markdown]
# It seems to be that there is a correlation between how many people have seen each movie and its rating, as the higher rated movies (#5) are also the more seen ones.

# %% [markdown]
# # Split data by groups

# %%
males = star_wars.copy()[star_wars["Gender"] == "Male"]
females = star_wars.copy()[star_wars["Gender"] == "Female"]

sw_fans = star_wars.copy()[star_wars["Do you consider yourself to be a fan of the Star Wars film franchise?"] == True]
sw_not_fans = star_wars.copy()[star_wars["Do you consider yourself to be a fan of the Star Wars film franchise?"] == False]

st_fans = star_wars.copy()[star_wars["Do you consider yourself to be a fan of the Star Trek franchise?"] == True]
st_not_fans = star_wars.copy()[star_wars["Do you consider yourself to be a fan of the Star Trek franchise?"] == False]

# %%
#gender based analysis
#Movie ranking
ranking_mean_male=males[males.columns[9:15]].mean()
ranking_mean_male.plot(kind='bar', title='Males ranking')
plt.show()

ranking_mean_female=females[females.columns[9:15]].mean()
ranking_mean_female.plot(kind='bar', title='Females ranking')
plt.show()

'''
seen_mean=star_wars[star_wars.columns[3:9]].sum()
seen_mean.plot(kind='bar')
plt.show()
'''
# Out:
# "\nseen_mean=star_wars[star_wars.columns[3:9]].sum()\nseen_mean.plot(kind='bar')\nplt.show()\n"

# %%
#gender based analysis
#people who watched
seen_mean_male=males[males.columns[3:9]].sum()
seen_mean_male.plot(kind='bar', title='Male viewership')
plt.show()

seen_mean_female=females[females.columns[3:9]].sum()
seen_mean_female.plot(kind='bar', title='Female Viewership')
plt.show()
